# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/Users/alisdghnia/Desktop/Research Datasets/')

# %%
df = pd.read_csv('regression_pvalue_without_btc&eth.csv')

# %%
# top 50 terms
df = df.head(53)

# %%
df
# Out:
#              Term  Coefficients  Standard_Errors  t_Value  P_Value
# 0          turing       10.7931            2.585    4.175    0.001
# 1            burn       -7.5610            2.130   -3.550    0.002
# 2         mwallet      122.0606           16.702    7.308    0.005
# 3      segregated      117.5255           36.793    3.194    0.005
# 4           fault       27.1185            8.449    3.210    0.005
# 5             roi       11.5312            3.703    3.114    0.006
# 6       financial        8.0905            2.618    3.090    0.007
# 7         presale       32.1046           11.624    2.762    0.013
# 8          secret       10.5599            3.880    2.722    0.014
# 9      currencies       17.3270            6.356    2.726    0.014
# 10           ramp      -96.3347           35.904   -2.683    0.015
# 11       sharding       17.5558            6.774    2.592    0.018
# 12            btc       -6.3980            2.469   -2.591    0.018
# ...

# %%
df.to_csv('top_53_terms.csv')
