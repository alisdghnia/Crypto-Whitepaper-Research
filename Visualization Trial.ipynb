# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/Users/alisdghnia/Desktop/')

# %%
df = pd.read_excel('Full Dataset Cleaned Numbers Converted.xlsx')

# %%
df = df.drop(['Unnamed: 0'], axis='columns')

# %%
df
# Out:
#                     Name  File Size (MB)  Number of Pages  Word Count  \
# 0           WeTrust1.pdf        1.342260               40       12504
# 1             Libra4.pdf        0.293671               41       17474
# 2              B2BX1.pdf       15.404950               42           1
# 3             Bytom1.pdf        0.374002               17        4536
# 4        Cindicator1.pdf        1.123809               37       15509
# ..                   ...             ...              ...         ...
# 549         CPChain1.pdf        1.195266               34        7203
# 550       Presearch2.pdf        5.291211               39       12904
# 551         Electra1.pdf        0.624846               34        5508
# 552      Blockmason1.pdf        3.355893               31       13640
# 553  Nucleus-Vision1.pdf        0.900639                1         409
#
#      Flesch Reading Ease  New Dale-Chall  Abstract Section  Summary Section  \
# 0                  43.02            7.33                 1                0
# 1                  54.42            6.51                 1                0
# 2                 121.22           19.48                 0                0
# 3                  34.15            7.79                 1                0
# 4                  42.92            7.08                 0                0
# ..                   ...             ...               ...              ...
# 549                40.28            6.96                 0                0
# 550                41.70            7.16                 1                0
# 551                37.13            9.05                 1                1
# 552                49.04            7.00                 0                0
# 553                36.12           12.53                 0                0
#
#      Reference Section                     Crypto Name  Price (Intraday)  \
# 0                    1                     WeTrust USD      2.483000e-03
# 1                    1                      Libera USD      4.740480e-01
# 2                    0                           X USD      6.870000e-04
# 3                    1                       Bytom USD      1.237500e-02
# 4                    0                  Cindicator USD      6.710000e-04
# ..                 ...                             ...               ...
# 549                  0                     CPChain USD      3.619000e-03
# 550                  0                   Presearch USD      8.353100e-02
# 551                  0                     Electra USD      4.600000e-07
# 552                  0  Blockmason Credit Protocol USD      2.440000e-03
# 553                  0              Genesis Vision USD      2.341660e-01
#
#      Market Cap  Volume in Currency (24Hr)  Circulating Supply
# 0      228813.0                        3.0        9.214800e+07
# 1           0.0                      131.0        0.000000e+00
# 2           0.0                     9220.0        0.000000e+00
# 3    21831000.0                  1088000.0        1.764000e+09
# 4     1342000.0                       65.0        2.000000e+09
# ..          ...                        ...                 ...
# 549   1363000.0                   111473.0        3.767660e+08
# 550  33127000.0                   107073.0        3.965780e+08
# 551         0.0                       48.0        0.000000e+00
# 552    283474.0                        9.0        1.161590e+08
# 553   1037000.0                     1326.0        4.427000e+06
#
# [554 rows x 14 columns]

# %%
plt.scatter(df['Flesch Reading Ease'], df['Word Count'])
