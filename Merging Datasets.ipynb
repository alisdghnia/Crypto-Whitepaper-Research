# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import os

# %%
os.chdir('/Users/alisdghnia/Desktop/Data CSV Files/')

# %%
dep_data = pd.read_csv('Yahoo Finance Success Factors 1-10000.csv')
dep_data
# Out:
#       Unnamed: 0                                Name  Price (Intraday)  \
# 0              1                         Bitcoin USD      22908.160000
# 1              2                        Ethereum USD       1682.820000
# 2              3                          Tether USD          1.000200
# 3              4                        USD Coin USD          0.999791
# 4              5                    Binance Coin USD        321.640000
# ...          ...                                 ...               ...
# 9995        9996                 Tuzlaspor Token USD          0.616437
# 9996        9997                  AmazingTeamDAO USD         26.250000
# 9997        9998  Fantastic Protocol SNOWY Token USD          0.000270
# 9998        9999                      SpaceGrime USD          0.000000
# 9999       10000              SaunaFinance Token USD          0.001211
#
#      % Change Market Cap Volume in Currency (Since 0:00 UTC)  \
# ...

# %%
ind_data = pd.read_csv('Master Data Sheet Fixed 4.csv')
ind_data
# Out:
#      Unnamed: 0                 Name  File Size (MB)  Number of Pages  \
# 0             0         WeTrust1.pdf        1.342260               40
# 1             1           Libra4.pdf        0.293671               41
# 2             2            B2BX1.pdf       15.404950               42
# 3             3           Bytom1.pdf        0.374002               17
# 4             4      Cindicator1.pdf        1.123809               37
# ..          ...                  ...             ...              ...
# 551         551         CPChain1.pdf        1.195266               34
# 552         552       Presearch2.pdf        5.291211               39
# 553         553         Electra1.pdf        0.624846               34
# 554         554      Blockmason1.pdf        3.355893               31
# 555         555  Nucleus-Vision1.pdf        0.900639                1
#
#      Word Count  Flesch Reading Ease  New Dale-Chall  Abstract Section  \
# ...

# %%
ind_data['Crypto Name'] = ind_data['Name'].map(lambda x: process.extractOne(x, dep_data['Name'])[0])

# %%
ind_data
# Out:
#      Unnamed: 0                 Name  File Size (MB)  Number of Pages  \
# 0             0         WeTrust1.pdf        1.342260               40
# 1             1           Libra4.pdf        0.293671               41
# 2             2            B2BX1.pdf       15.404950               42
# 3             3           Bytom1.pdf        0.374002               17
# 4             4      Cindicator1.pdf        1.123809               37
# ..          ...                  ...             ...              ...
# 551         551         CPChain1.pdf        1.195266               34
# 552         552       Presearch2.pdf        5.291211               39
# 553         553         Electra1.pdf        0.624846               34
# 554         554      Blockmason1.pdf        3.355893               31
# 555         555  Nucleus-Vision1.pdf        0.900639                1
#
#      Word Count  Flesch Reading Ease  New Dale-Chall  Abstract Section  \
# ...

# %%
ind_data.to_csv('Independent Data + Dependent Names.csv', index = False)
