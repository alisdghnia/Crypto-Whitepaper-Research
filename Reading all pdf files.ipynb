# %%
import PyPDF2
import pandas as pd
import os
import io
import numpy as np
import spacy

# %%
path = '/Users/alisdghnia/Desktop/PDF Whitepapers'
for pdf_file in path:
    def getPageCount(pdf_file):
        pdfFileObj = open(pdf_file, 'rb')
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
        pages = pdfReader.numPages
        return pages


    def extractData(pdf_file, page):
        pdfFileObj = open(pdf_file, 'rb')
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
        pageObj = pdfReader.getPage(page)
        data = pageObj.extractText()
        return data
    
    def getwordCount(data):
        count = data.split()
        return count

# %%
pdffile = '/Users/alisdghnia/Desktop/whitepapers/AirSwap/SwapWhitepaper.pdf'
numpages = getPageCount(pdffile)
print(numpages)
# Out:
# 13

# %%
for i in range(0 , numpages):
    token = extractData(pdffile, i)
    print(token)
# Out:
#  Swap: A Peer-to-Peer Protocol for
# Trading Ethereum Tokens
# Michael Oved, Don Mosites
# June 21, 2017
# team@swap.tech
# Abstract
# We present a peer-to-peer methodology for trading ERC20 tokens on the Ethereum blockchain.
# First, we outline the limitations of blockchain order books and oer a strong alternative in
# peer-to-peer token trading: o-chain negotiation and on-chain settlement. We then describe
# a protocol through which parties are able to signal to others their intent to trade tokens. Once
# connected, counterparties freely communicate prices and transmit orders among themselves.
# During this process, parties may request prices from an independent third party oracle
# to verify accuracy. Finally, we present an Ethereum smart contract to ll orders on the
# Ethereum blockchain.
# 1
# 1) Introduction
# The number of digital assets on Ethereum over the past twelve months has increased aggressively
# ...

# %%
os.chdir('/Users/alisdghnia/Desktop/PDF Whitepapers')
wordCountPerPage = []
for (dirname,dirs,files) in os.walk('.'):
    for filename in files:
        if filename.endswith('.pdf'):
            thefile = os.path.join(filename)
            path = thefile
            numpages = getPageCount(path)
            for i in range(0, numpages):
                token = extractData(filename, i)
                print(filename, "( ", i+1, " )" " : " , len(token))
                #wordCountPerPage.append(token)
# Out:
# en_whitepaper.pdf (  1  ) :  913
# en_whitepaper.pdf (  2  ) :  2081
# en_whitepaper.pdf (  3  ) :  4349
# en_whitepaper.pdf (  4  ) :  2269
# en_whitepaper.pdf (  5  ) :  2311
# en_whitepaper.pdf (  6  ) :  1814
# en_whitepaper.pdf (  7  ) :  2137
# en_whitepaper.pdf (  8  ) :  1495
# en_whitepaper.pdf (  9  ) :  1909
# en_whitepaper.pdf (  10  ) :  2272
# en_whitepaper.pdf (  11  ) :  2202
# en_whitepaper.pdf (  12  ) :  1446
# en_whitepaper.pdf (  13  ) :  2809
# en_whitepaper.pdf (  14  ) :  3062
# en_whitepaper.pdf (  15  ) :  13
# 216.pdf (  1  ) :  2344
# 216.pdf (  2  ) :  3269
# 216.pdf (  3  ) :  3314
# 216.pdf (  4  ) :  3065
# 216.pdf (  5  ) :  2856
# 216.pdf (  6  ) :  2080
# 216.pdf (  7  ) :  2694
# 216.pdf (  8  ) :  2876
# 216.pdf (  9  ) :  2644
# 216.pdf (  10  ) :  2612
# 216.pdf (  11  ) :  3103
# 216.pdf (  12  ) :  2379
# 216.pdf (  13  ) :  2588
# 216.pdf (  14  ) :  2592
# 216.pdf (  15  ) :  2367
# 216.pdf (  16  ) :  2655
# 216.pdf (  17  ) :  2826
# ...

# %%
for (dirname,dirs,files) in os.walk('.'):
    for filename in files:
        if filename.endswith('.pdf'):
            thefile = os.path.join(filename)
            print(thefile)
# Out:
# en_whitepaper.pdf
# 216.pdf
# SWIRLDS-TR-2016-01.pdf
# 1910.11143.pdf
# protocol.pdf
# libra-move-a-language-with-programmable-resources.pdf
# SyncFab_MFG_WP.pdf
# 1153.pdf
# bitcoin.pdf
# EOS_An_Introduction.pdf
# tenx_whitepaper_final.pdf
# Binance_WhitePaper_en_v1.2.pdf
# maymounkov-kademlia-lncs.pdf
# Datum-WhitePaper.pdf
# v2.1.pdf
# Whitepaper - Eximchain.pdf
# patientory_whitepaper.pdf
# electra-white-paper_1.0.pdf
# Polkadot-lightpaper-2020.pdf
# MasterCoin Specification 1.1.pdf
# aelf_whitepaper_v1.2.pdf
# Design_Book_of_TRON_Architecture1.4.pdf
# NAV-Coin-Whitepaper.pdf
# request_whitepaper.pdf
# UTRUST-whitepaper-en-2017-11-02.pdf
# Binance_WhitePaper_en.pdf
# defi-chain-modules.pdf
# White_Paper_EN.pdf
# 573.pdf
# SWIRLDS-TR-2016-02.pdf
# OriginTrail-White-Paper.pdf
# Lunyr_White_Paper_ENG.pdf
# Safecoin.pdf
# WhitePaper 58.pdf
# WhitePaperEn.pdf
# Ethereum_white_paper.pdf
# Dropil_White_Paper.pdf
# WT_OP_ENG.pdf
# ...

# %%
def eachPageCount(pdf_file):
    for i in range(0 , numpages):
        token = extractData(pdffile, i)
        print(token)

# %%
os.chdir('/Users/alisdghnia/Desktop/Data CSV Files')
.to_csv('All Folders and Files.csv',
            index = False)

# %%
print(wordCountPerPage)

# %%
# %pip install PyPDF2
# %pip install numpy
# %pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.3/101.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.4/456.4 kB 2.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.1 MB/s eta 0:00:00
# ...

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 4.9 MB 2.7 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached numpy-1.23.0.tar.gz (10.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 503 kB 1.4 MB/s eta 0:00:01
# ...
#   Created wheel for pandas: filename=pandas-1.4.3-cp38-cp38-macosx_10_14_arm64.whl size=17109684 sha256=323226fe0b0f5659078735bcb027e95e88e9e6d38699091353c02982cc3c0c4b
#   Stored in directory: /Users/alisdghnia/Library/Caches/pip/wheels/53/fa/96/a32fd6773ac8f1b905551d7a6b07c10d6dd49601d1ba871664
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# %pip install io
# %pip install os
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement io (from versions: none)
# ERROR: No matching distribution found for io
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# ...
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/Users/alisdghnia/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 2.1 MB 2.2 MB/s eta 0:00:01
# ...
#   WARNING: The scripts pip, pip3, pip3.10 and pip3.8 are installed in '/Users/alisdghnia/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade python 3.10
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement python (from versions: none)
# ERROR: No matching distribution found for python
# Note: you may need to restart the kernel to use updated packages.
