# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
import glob
import re
import os
from io import StringIO
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import TextConverter
import PyPDF2
def get_pdf_file_content(path_to_pdf):
    '''
    path_to_pdf: is the parameter that will give access to the PDF File 
    we want to extract the content.
    '''
    '''
    PDFResourceManager is used to store shared resources such as fonts or images that 
    we might encounter in the files. 
    '''
    resource_manager = PDFResourceManager(caching=True)
    '''
    create a string object that will contain the final text the representation of the pdf. 
    '''
    out_text = StringIO()
    '''
    UTF-8 is one of the most commonly used encodings, and Python often defaults to using it.
    In our case, we are going to specify in order to avoid some encoding errors.
    '''
    codec = 'utf-8'
    """
    LAParams is the object containing the Layout parameters with a certain default value. 
    """
    laParams = LAParams()
    '''
    Create a TextConverter Object, taking :
    - ressource_manager,
    - out_text 
    - layout parameters.
    '''
    text_converter = TextConverter(resource_manager, out_text, laparams=laParams)
    fp = open(path_to_pdf, 'rb')
    
    '''
    Create a PDF interpreter object taking: 
    - ressource_manager 
    - text_converter
    '''
    interpreter = PDFPageInterpreter(resource_manager, text_converter)
    '''
    We are going to process the content of each page of the original PDF File
    '''
    for page in PDFPage.get_pages(fp, pagenos=set(), maxpages=10000000, password="", caching=True, check_extractable=False):
        interpreter.process_page(page)
    '''
    Retrieve the entire contents of the “file” at any time 
    before the StringIO object’s close() method is called.
    '''
    text = out_text.getvalue()
    '''
    Closing all the ressources we previously opened
    '''
    fp.close()
    text_converter.close()
    out_text.close()
    '''
    Return the final variable containing all the text of the PDF
    '''
    return text

path_to_pdf = "/Users/alisdghnia/Desktop/Helium.pdf"
Al=get_pdf_file_content(path_to_pdf)
#print(Al.count("¶"))
#changer = Al.find("¶")
Al = Al.replace("¶a","á")
Al = Al.replace("¶e","é")
Al = Al.replace("¶‡","í")
Al = Al.replace("¶o","ó")
Al = Al.replace("¶u","ú")
Al = Al.replace("~n","ñ")
Al = Al.replace("¶A","Á")
Al = Al.replace("\\",'"')
#print(changer)
#print(Al)
##print(Al.count('\\'))
##print(Al)

words = Al.split()

# %%
os.chdir('/Users/alisdghnia/Desktop/PDF Whitepapers Copy/')

# %%
names = []
for (dirname, dirs, files) in os.walk('/Users/alisdghnia/Desktop/PDF Whitepapers Copy/'):
    filenames = filter((lambda x: x.endswith('.pdf')), files)
    for filename in filenames:
        name = filename.split('.pdf')[0]
        names.append(name)

names
# Out:
# ['WeTrust1',
#  'Libra4',
#  'B2BX1',
#  'Bytom1',
#  'Cindicator1',
#  'iXledger1',
#  'FARAD1',
#  'DomRaider1',
#  'Zeusshield1',
#  'Steem1',
#  'Blocknet1',
#  'Chronobank1',
#  'iExec1',
#  'Syscoin1',
#  'Gulden1',
#  'Winding-Tree2',
#  'maymounkov-kademlia-lncs',
#  'Cardano1',
#  'CoinDash1',
#  'Pundi-X1',
#  'vSlice1',
#  'ODYSSEY1',
#  'Iconomi1',
#  'Aeron1',
#  'Metal1',
#  'CoinStarter1',
#  'Bancor1',
#  'openANX1',
#  'Zilliqa2',
#  'Rebellious1',
#  'Minexcoin1',
#  'Numeraire1',
#  'Qbao1',
#  'Cappasity1',
#  'Privatix1',
#  'Streamr1',
#  'AirSwap1',
#  'Avalanche1',
#  'ICOS1',
#  'RIALTO.AI1',
#  'CyberVein1',
#  'Enigma1',
#  'WaBi1',
#  'Cardano3',
#  'Winding-Tree1',
#  'Synereo1',
#  'GATCOIN1',
#  'Monaco1',
#  'Cardano2',
#  'HOQU1',
#  'Nebulas1',
#  'Oyster1',
#  'DigiPulse1',
#  'openANX2',
#  'Zilliqa1',
#  'NAGA1',
#  'Earth-Token1',
#  'Curriculum-Vitae1',
#  'Kin1',
#  'Lamden1',
#  'Libra2',
#  'Blockport1',
#  'Ethereum-Classic1',
#  'Coinlancer1',
#  'Bounty0x1',
#  'Genesis-Vision1',
#  'MobileGo1',
#  'FundYourselfNow1',
#  'Opus1',
#  'DigitalNote1',
#  'CREDITS2',
#  'Komodo1',
#  '199',
#  'COSS1',
#  'PayPie1',
#  'TrueChain1',
#  'Reddcoin1',
#  'Dragonchain1',
#  'Omni2',
#  'VeChain2',
#  'VeChain3',
#  'Omni3',
#  'rfc6330',
#  'aelf1',
#  'Melon1',
#  'Karma1',
#  'XPA1',
#  'Verge1',
#  'SelfKey1',
#  'DTR1',
#  'EchoLink1',
#  'NavCoin1',
#  'Libra3',
#  'Libra1',
#  'Aventus1',
#  'Blackmoon1',
#  'Verify1',
#  'MobileGo2',
#  'Civic1',
#  'Request-Network1',
#  'Experience-Points1',
#  'CREDITS1',
#  'secure-names-bit-strings',
#  'Karma3',
#  'TrueChain2',
#  'Eidoo1',
#  'Omni1',
#  'Ormeus1',
#  'VeChain1',
#  'Cardano5',
#  'Polymath1',
#  'Cardano4',
#  'Solana1',
#  'Karma2',
#  'Stipend1',
#  'CUBE1',
#  'SelfKey2',
#  'Matryx1',
#  'WePower1',
#  'InsurePal1',
#  'DFINITY4',
#  'Playkey1',
#  'trade.io1',
#  'LinkEye1',
#  'All-Sports1',
#  'FUSION1',
#  'Aditus1',
#  'TenX1',
#  'TomoChain1',
#  'Fantom1',
#  'Nexus1',
#  'Centra1',
#  'Ontology1',
#  'WAX1',
#  'Revain1',
#  'aXpire2',
#  'Maker1',
#  'Qtum1',
#  'Exchange-Union1',
#  'Haven-Protocol1',
#  'Target-Coin2',
#  'Groestlcoin1',
#  'Rivetz1',
#  'ArcBlock1',
#  'Wings2',
#  'Polkastarter1',
#  'spineless-tagless-gmachine',
#  'Authorship1',
#  'Cryptonote1',
#  'TRON1',
#  'Stratis1',
#  'TRON3',
#  '0x1',
#  'AdEx1',
#  'Kyvalion1',
#  'Nano1',
#  'RChain1',
#  'TenX2',
#  'Fantom2',
#  'Ripio-Credit-Network1',
#  'Ontology2',
#  'aXpire1',
#  'time-stamp-digital-document',
#  'Delphy1',
#  'Primas1',
#  'Golem1',
#  'Wrapped-Bitcoin1',
#  'BitStation1',
#  'Grid+1',
#  'Zap1',
#  'Qtum2',
#  'CanYa1',
#  'osdi99',
#  'Paypex1',
#  'Eximchain1',
#  'SWFT1',
#  'Target-Coin1',
#  'adToken1',
#  'IP-Exchange1',
#  'APEX1',
#  'Ontology3',
#  'Dash1',
#  'Fantom3',
#  'Nework1',
#  'Decent.bet1',
#  'Databits1',
#  'Wings1',
#  'Bankera1',
#  'Zerocoin1',
#  'QASH1',
#  'Havven1',
#  'VIBE1',
#  'StockChain1',
#  'TRON2',
#  'DFINITY2',
#  'Creativecoin1',
#  'Gnosis1',
#  'MediShares1',
#  'CoinMeet1',
#  'Red-Pulse1',
#  'SpankChain1',
#  'Embermine1',
#  'Snovio1',
#  'SophiaTX1',
#  'Neblio1',
#  'CRYPTO201',
#  'GBX1',
#  'PiplShare1',
#  'Fantom6',
#  'Bitsum1',
#  'Waves1',
#  'Swirlds2',
#  'VOISE2',
#  'Zerocash1',
#  'Binance1',
#  'Monero8',
#  'FunFair1',
#  'Wagerr1',
#  'Polybius1',
#  'Dentacoin1',
#  'DFINITY3',
#  'Energo1',
#  'Mothership1',
#  'Ripple1',
#  'DFINITY1',
#  'Bluzelle1',
#  'Populous1',
#  'Achain1',
#  'LeadCoin1',
#  'Fantom4',
#  'Soar1',
#  'Stox1',
#  'IOTA1',
#  'Olympus-Labs1',
#  'Etherparty1',
#  'Bitcoin-Private2',
#  'Walton1',
#  'USD-Coin1',
#  'Docademic1',
#  'Swirlds1',
#  'Fantom5',
#  'Zerocash2',
#  'Binance2',
#  'VOISE1',
#  'SingularityNET1',
#  'Asch1',
#  'Crypti1',
#  'Emercoin1',
#  'Byteball1',
#  'SportyFi1',
#  'Ethereum2',
#  'aeternity2',
#  'Vertcoin2',
#  'JET84',
#  'Aurora1',
#  'Enjin1',
#  'Horizon-State1',
#  'BOScoin2',
#  'Monero6',
#  'ZenCash1',
#  'Fantom8',
#  'DigixDAO1',
#  'Leverj1',
#  'Algorand3',
#  'Nexo2',
#  'DATx1',
#  'BitClave1',
#  'Santiment1',
#  'SingularDTV1',
#  'WaykiChain1',
#  'TokenPay1',
#  'Algorand2',
#  'Nexo3',
#  'Mysterium1',
#  'DATA2',
#  'Fantom9',
#  'EOS1',
#  'BnKToTheFuture1',
#  'DADI2',
#  'Monero7',
#  'BOScoin3',
#  'Quantum-Resistant-Ledger1',
#  'Quantstamp1',
#  'KyberNetwork1',
#  'SONM1',
#  'Augur1',
#  'Ethereum3',
#  'BlitzPredict1',
#  'Ethereum1',
#  'aeternity1',
#  'Vertcoin1',
#  'Genaro-Network4',
#  'ICON1',
#  'IHT1',
#  'Astronaut1',
#  'Substratum1',
#  'MOAC1',
#  'Monero5',
#  'BOScoin1',
#  'Zcoin1',
#  'CommerceBlock1',
#  'Nexo1',
#  'Elastos1',
#  'Stellite1',
#  'STK1',
#  'Centrality1',
#  'improving-time-stamping',
#  'Vice-Industry-Token1',
#  'Algorand1',
#  'OmiseGO1',
#  'GXChain1',
#  'DATA1',
#  'EOS2',
#  'DADI1',
#  'Flixxo1',
#  'BnKToTheFuture2',
#  'Factom1',
#  'Darcrus1',
#  'Monero4',
#  'Envion1',
#  'Fantom10',
#  'CACM-1999',
#  'Cobinhood1',
#  'BlitzPredict2',
#  'Safex1',
#  'hott-online-1132-g5052dbc',
#  'Cosmos1',
#  'Cortex1',
#  'AppCoins1',
#  'bitqy1',
#  'JET82',
#  'Genaro-Network1',
#  'FoldingCoin1',
#  'BlockCAT1',
#  'Bezop1',
#  'BitTorrent1',
#  'TokenCard1',
#  'True-Flip1',
#  'Storiqa1',
#  'modum1',
#  'Universa1',
#  'Lympo1',
#  'Bloom1',
#  'ChainLink1',
#  'Zcash1',
#  'Algorand5',
#  'PolySwarm1',
#  'Storm1',
#  'Bitquence1',
#  'Patientory1',
#  'Friendz2',
#  'SyncFab1',
#  'Po.et1',
#  'ABBC1',
#  'Tokes1',
#  'Algorand4',
#  'MaidSafe1',
#  'Beluga-Pay1',
#  'CoinMetro1',
#  'Quantum1',
#  'Sentinel-Chain1',
#  'LATOKEN1',
#  'SwissBorg1',
#  'Monero1',
#  'Loopring2',
#  'UTRUST1',
#  'Ethos1',
#  'Legolas-Exchange1',
#  'Dent1',
#  'JET83',
#  'Metaverse1',
#  'SpaceChain1',
#  'Theta2',
#  'secure-timestamping-service',
#  'byzantine',
#  'AppCoins2',
#  'JET81',
#  'MATRIX1',
#  'Genaro-Network2',
#  'GIFTO1',
#  'Bezop2',
#  'TNB1',
#  'Monero3',
#  'INT1',
#  'UQUID1',
#  'Friendz1',
#  'Zcash3',
#  'ATLANT1',
#  'QunQun1',
#  'Tierion1',
#  'Tether1',
#  'Monero2',
#  'Cryptonex1',
#  'HPB1',
#  'Lykke1',
#  'Genaro-Network3',
#  'Loopring1',
#  'Filecoin1',
#  'SALT1',
#  'Metaverse2',
#  'Refereum1',
#  'Theta1',
#  'Mithril1',
#  'XTRABYTES1',
#  'Effect2',
#  'Swarm1',
#  'Polkadot2',
#  'MyBit1',
#  'Autonio1',
#  'PIVX1',
#  'CyberMiles2',
#  'Jibrel-Network1',
#  'Dropil1',
#  'SmartMesh1',
#  'CloakCoin1',
#  'BitShares2',
#  'Trinity1',
#  'BitShares3',
#  'Fortuna1',
#  'Brahma-OS1',
#  'ATMChain1',
#  'YOYOW1',
#  'Storj1',
#  'Covesting1',
#  'MCAP1',
#  'DeepBrain-Chain1',
#  'SIRIN-LABS1',
#  'AidCoin1',
#  'Crypterium1',
#  'Blocklancer1',
#  'Bibox1',
#  'Sky1',
#  'Change1',
#  'Tezos1',
#  'MediBloc1',
#  'Polkadot3',
#  'OriginTrail1',
#  'Neufund1',
#  'Zclassic2',
#  'CoinPoker1',
#  'Effect1',
#  'Holo1',
#  'Polkadot1',
#  'KuCoin1',
#  'public-key-cryptosystem',
#  'BitcoinDark1',
#  'Sky3',
#  'THEKEY1',
#  'Blocklancer3',
#  'Daneel1',
#  'ODEM1',
#  'CyberMiles1',
#  'BitShares1',
#  'PPCoin1',
#  'Agrello1',
#  'Simple-Token1',
#  'Paragon1',
#  'Burst1',
#  '2005-Book-Reliable Distributed Systems',
#  'GreenMed1',
#  'AidCoin2',
#  'Bodhi1',
#  'Blocklancer2',
#  'Bitcoin1',
#  'INS1',
#  'Wanchain1',
#  'Sky2',
#  'Tezos2',
#  'Change2',
#  'Nxt1',
#  'Bread1',
#  'Edgeless1',
#  'Particl1',
#  'Terra1',
#  'Consensus2',
#  'Humaniq1',
#  'district0x1',
#  'Ambrosus1',
#  'Aave1',
#  'ARK1',
#  'Pillar1',
#  'TON2',
#  'Zeepin1',
#  'Stellar1',
#  'NEM1',
#  'Global-Jobcoin1',
#  'TaaS1',
#  'Bitcoin-Gold1',
#  'Aragon1',
#  'UnikoinGold1',
#  'Titanium1',
#  'REMME1',
#  'Maecenas1',
#  'AICHAIN1',
#  'NULS2',
#  'Mixin1',
#  'Power-Ledger1',
#  'Ardor1',
#  'Rentberry1',
#  'Aion1',
#  'Everex1',
#  'Hcash1',
#  'Antshares1',
#  'Electrify.Asia1',
#  'Etheroll1',
#  'Datum1',
#  'Decentraland1',
#  'NVO1',
#  'Electra2',
#  'CPChain2',
#  'Presearch1',
#  'BOTTOS1',
#  'Ethorse1',
#  'Nucleus-Vision2',
#  'BLOCKv1',
#  'Consensus1',
#  'Paxos-Standard1',
#  'Decred1',
#  'Aave2',
#  'Minereum1',
#  'Uniswap1',
#  'Sky5',
#  'Sia1',
#  'Klaytn1',
#  'TON1',
#  'Rentberry3',
#  'Basic-Attention-Token1',
#  'Global-Jobcoin2',
#  'hashcash',
#  'Xaurum1',
#  'ClearCoin1',
#  'VITE1',
#  'Moeda1',
#  'Lunyr1',
#  'Ink1',
#  'NULS1',
#  'AICHAIN2',
#  'RaiBlocks1',
#  'Hcash2',
#  'Rentberry2',
#  'Ravencoin1',
#  'Telcoin1',
#  'NuBits1',
#  'Electrify.Asia2',
#  'indaHash1',
#  'BANKEX1',
#  'Sky4',
#  'Auctus1',
#  'Monetha1',
#  'IoT-Chain1',
#  'Status1',
#  'CPChain1',
#  'Presearch2',
#  'Electra1',
#  'Blockmason1',
#  'Nucleus-Vision1']

# %%
corpus = {}
for (dirname, dirs, files) in os.walk('/Users/alisdghnia/Desktop/PDF Whitepapers Copy/'):
    filenames = filter((lambda x: x.endswith('.pdf')), files)
    for filename in filenames:
        name = filename.split('.pdf')[0]
        print(name)
        try:
            text = get_pdf_file_content(filename)
        except Exception:
            pass
        
        text = text.lower()
        corpus[name] = text
        
df = pd.DataFrame(corpus, index = names)
df
# Out:
# WeTrust1
# Libra4
# B2BX1
# Bytom1
# Cindicator1
# iXledger1
# FARAD1
# DomRaider1
# Zeusshield1
# Steem1
# Blocknet1
# Chronobank1
# iExec1
# Syscoin1
# Gulden1
# Winding-Tree2
# maymounkov-kademlia-lncs
# Cardano1
# CoinDash1
# Pundi-X1
# vSlice1
# ODYSSEY1
# Iconomi1
# Aeron1
# Metal1
# CoinStarter1
# Bancor1
# openANX1
# Zilliqa2
# Rebellious1
# Minexcoin1
# Numeraire1
# Qbao1
# Cappasity1
# Privatix1
# Streamr1
# AirSwap1
# Avalanche1
# ICOS1
# RIALTO.AI1
# CyberVein1
# Enigma1
# WaBi1
# Cardano3
# Winding-Tree1
# Synereo1
# GATCOIN1
# Monaco1
# Cardano2
# HOQU1
# Nebulas1
# Oyster1
# DigiPulse1
# openANX2
# Zilliqa1
# NAGA1
# Earth-Token1
# Curriculum-Vitae1
# Kin1
# Lamden1
# Libra2
# Blockport1
# Ethereum-Classic1
# Coinlancer1
# Bounty0x1
# Genesis-Vision1
# MobileGo1
# FundYourselfNow1
# Opus1
# DigitalNote1
# CREDITS2
# Komodo1
# 199
# COSS1
# PayPie1
# TrueChain1
# Reddcoin1
# Dragonchain1
# Omni2
# VeChain2
# VeChain3
# Omni3
# rfc6330
# aelf1
# Melon1
# Karma1
# XPA1
# Verge1
# SelfKey1
# DTR1
# EchoLink1
# NavCoin1
# Libra3
# Libra1
# Aventus1
# Blackmoon1
# Verify1
# MobileGo2
# Civic1
# Request-Network1
# Experience-Points1
# CREDITS1
# secure-names-bit-strings
# Karma3
# TrueChain2
# Eidoo1
# Omni1
# Ormeus1
# VeChain1
# Cardano5
# Polymath1
# Cardano4
# Solana1
# Karma2
# Stipend1
# CUBE1
# SelfKey2
# Matryx1
# WePower1
# InsurePal1
# DFINITY4
# Playkey1
# trade.io1
# LinkEye1
# All-Sports1
# FUSION1
# Aditus1
# TenX1
# TomoChain1
# Fantom1
# Nexus1
# Centra1
# Ontology1
# WAX1
# Revain1
# aXpire2
# Maker1
# Qtum1
# Exchange-Union1
# Haven-Protocol1
# Target-Coin2
# Groestlcoin1
# Rivetz1
# ArcBlock1
# Wings2
# Polkastarter1
# spineless-tagless-gmachine
# Authorship1
# Cryptonote1
# TRON1
# Stratis1
# TRON3
# 0x1
# AdEx1
# Kyvalion1
# Nano1
# RChain1
# TenX2
# Fantom2
# Ripio-Credit-Network1
# Ontology2
# aXpire1
# time-stamp-digital-document
# Delphy1
# Primas1
# Golem1
# Wrapped-Bitcoin1
# BitStation1
# Grid+1
# Zap1
# Qtum2
# CanYa1
# osdi99
# Paypex1
# Eximchain1
# SWFT1
# Target-Coin1
# adToken1
# IP-Exchange1
# APEX1
# Ontology3
# Dash1
# Fantom3
# Nework1
# Decent.bet1
# Databits1
# Wings1
# Bankera1
# Zerocoin1
# QASH1
# Havven1
# VIBE1
# StockChain1
# TRON2
# DFINITY2
# Creativecoin1
# Gnosis1
# MediShares1
# CoinMeet1
# Red-Pulse1
# SpankChain1
# Embermine1
# Snovio1
# SophiaTX1
# Neblio1
# CRYPTO201
# GBX1
# PiplShare1
# Fantom6
# Bitsum1
# Waves1
# Swirlds2
# VOISE2
# Zerocash1
# Binance1
# Monero8
# FunFair1
# Wagerr1
# Polybius1
# Dentacoin1
# DFINITY3
# Energo1
# Mothership1
# Ripple1
# DFINITY1
# Bluzelle1
# Populous1
# Achain1
# LeadCoin1
# Fantom4
# Soar1
# Stox1
# IOTA1
# Olympus-Labs1
# Etherparty1
# Bitcoin-Private2
# Walton1
# USD-Coin1
# Docademic1
# Swirlds1
# Fantom5
# Zerocash2
# Binance2
# VOISE1
# SingularityNET1
# Asch1
# Crypti1
# Emercoin1
# Byteball1
# SportyFi1
# Ethereum2
# aeternity2
# Vertcoin2
# JET84
# Aurora1
# Enjin1
# Horizon-State1
# BOScoin2
# Monero6
# ZenCash1
# Fantom8
# DigixDAO1
# Leverj1
# Algorand3
# Nexo2
# DATx1
# BitClave1
# Santiment1
# SingularDTV1
# WaykiChain1
# TokenPay1
# Algorand2
# Nexo3
# Mysterium1
# DATA2
# Fantom9
# EOS1
# BnKToTheFuture1
# DADI2
# Monero7
# BOScoin3
# Quantum-Resistant-Ledger1
# Quantstamp1
# KyberNetwork1
# SONM1
# Augur1
# Ethereum3
# BlitzPredict1
# Ethereum1
# aeternity1
# Vertcoin1
# Genaro-Network4
# ICON1
# IHT1
# Astronaut1
# Substratum1
# MOAC1
# Monero5
# BOScoin1
# Zcoin1
# CommerceBlock1
# Nexo1
# Elastos1
# Stellite1
# STK1
# Centrality1
# improving-time-stamping
# Vice-Industry-Token1
# Algorand1
# OmiseGO1
# GXChain1
# DATA1
# EOS2
# DADI1
# Flixxo1
# BnKToTheFuture2
# Factom1
# Darcrus1
# Monero4
# Envion1
# Fantom10
# CACM-1999
# Cobinhood1
# BlitzPredict2
# Safex1
# hott-online-1132-g5052dbc
# Cosmos1
# Cortex1
# AppCoins1
# bitqy1
# JET82
# Genaro-Network1
# FoldingCoin1
# BlockCAT1
# Bezop1
# BitTorrent1
# TokenCard1
# True-Flip1
# Storiqa1
# modum1
# Universa1
# Lympo1
# Bloom1
# ChainLink1
# Zcash1
# Algorand5
# PolySwarm1
# Storm1
# Bitquence1
# Patientory1
# Friendz2
# SyncFab1
# Po.et1
# ABBC1
# Tokes1
# Algorand4
# MaidSafe1
# Beluga-Pay1
# CoinMetro1
# Quantum1
# Sentinel-Chain1
# LATOKEN1
# SwissBorg1
# Monero1
# Loopring2
# UTRUST1
# Ethos1
# Legolas-Exchange1
# Dent1
# JET83
# Metaverse1
# SpaceChain1
# Theta2
# secure-timestamping-service
# byzantine
# AppCoins2
# JET81
# MATRIX1
# Genaro-Network2
# GIFTO1
# Bezop2
# TNB1
# Monero3
# INT1
# UQUID1
# Friendz1
# Zcash3
# ATLANT1
# QunQun1
# Tierion1
# Tether1
# Monero2
# Cryptonex1
# HPB1
# Lykke1
# Genaro-Network3
# Loopring1
# Filecoin1
# SALT1
# Metaverse2
# Refereum1
# Theta1
# Mithril1
# XTRABYTES1
# Effect2
# Swarm1
# Polkadot2
# MyBit1
# Autonio1
# PIVX1
# CyberMiles2
# Jibrel-Network1
# Dropil1
# SmartMesh1
# CloakCoin1
# BitShares2
# Trinity1
# BitShares3
# Fortuna1
# Brahma-OS1
# ATMChain1
# YOYOW1
# Storj1
# Covesting1
# MCAP1
# DeepBrain-Chain1
# SIRIN-LABS1
# AidCoin1
# Crypterium1
# Blocklancer1
# Bibox1
# Sky1
# Change1
# Tezos1
# MediBloc1
# Polkadot3
# OriginTrail1
# Neufund1
# Zclassic2
# CoinPoker1
# Effect1
# Holo1
# Polkadot1
# KuCoin1
# public-key-cryptosystem
# BitcoinDark1
# Sky3
# THEKEY1
# Blocklancer3
# Daneel1
# ODEM1
# CyberMiles1
# BitShares1
# PPCoin1
# Agrello1
# Simple-Token1
# Paragon1
# Burst1
# 2005-Book-Reliable Distributed Systems
# GreenMed1
# AidCoin2
# Bodhi1
# Blocklancer2
# Bitcoin1
# INS1
# Wanchain1
# Sky2
# Tezos2
# Change2
# Nxt1
# Bread1
# Edgeless1
# Particl1
# Terra1
# Consensus2
# Humaniq1
# district0x1
# Ambrosus1
# Aave1
# ARK1
# Pillar1
# TON2
# Zeepin1
# Stellar1
# NEM1
# Global-Jobcoin1
# TaaS1
# Bitcoin-Gold1
# Aragon1
# UnikoinGold1
# Titanium1
# REMME1
# Maecenas1
# AICHAIN1
# NULS2
# Mixin1
# Power-Ledger1
# Ardor1
# Rentberry1
# Aion1
# Everex1
# Hcash1
# Antshares1
# Electrify.Asia1
# Etheroll1
# Datum1
# Decentraland1
# NVO1
# Electra2
# CPChain2
# Presearch1
# BOTTOS1
# Ethorse1
# Nucleus-Vision2
# BLOCKv1
# Consensus1
# Paxos-Standard1
# Decred1
# Aave2
# Minereum1
# Uniswap1
# Sky5
# Sia1
# Klaytn1
# TON1
# Rentberry3
# Basic-Attention-Token1
# Global-Jobcoin2
# hashcash
# Xaurum1
# ClearCoin1
# VITE1
# Moeda1
# Lunyr1
# Ink1
# NULS1
# AICHAIN2
# RaiBlocks1
# Hcash2
# Rentberry2
# Ravencoin1
# Telcoin1
# NuBits1
# Electrify.Asia2
# indaHash1
# BANKEX1
# Sky4
# Auctus1
# Monetha1
# IoT-Chain1
# Status1
# CPChain1
# Presearch2
# Electra1
# Blockmason1
# Nucleus-Vision1
#                                                           WeTrust1  \
# WeTrust1         wetrust whitepaper table of contents \n\n \n\n...
# Libra4           wetrust whitepaper table of contents \n\n \n\n...
# B2BX1            wetrust whitepaper table of contents \n\n \n\n...
# Bytom1           wetrust whitepaper table of contents \n\n \n\n...
# Cindicator1      wetrust whitepaper table of contents \n\n \n\n...
# ...                                                            ...
# CPChain1         wetrust whitepaper table of contents \n\n \n\n...
# Presearch2       wetrust whitepaper table of contents \n\n \n\n...
# Electra1         wetrust whitepaper table of contents \n\n \n\n...
# Blockmason1      wetrust whitepaper table of contents \n\n \n\n...
# Nucleus-Vision1  wetrust whitepaper table of contents \n\n \n\n...
#
#                                                             Libra4  \
# WeTrust1         state machine replication in the libra\n\nbloc...
# Libra4           state machine replication in the libra\n\nbloc...
# B2BX1            state machine replication in the libra\n\nbloc...
# Bytom1           state machine replication in the libra\n\nbloc...
# Cindicator1      state machine replication in the libra\n\nbloc...
# ...                                                            ...
# CPChain1         state machine replication in the libra\n\nbloc...
# Presearch2       state machine replication in the libra\n\nbloc...
# Electra1         state machine replication in the libra\n\nbloc...
# Blockmason1      state machine replication in the libra\n\nbloc...
# Nucleus-Vision1  state machine replication in the libra\n\nbloc...
#
#                                                             B2BX1  \
# WeTrust1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Libra4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# B2BX1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bytom1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cindicator1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...                                                           ...
# CPChain1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Presearch2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Electra1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Blockmason1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nucleus-Vision1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                             Bytom1  \
# WeTrust1         bytomv1.0                                     ...
# Libra4           bytomv1.0                                     ...
# B2BX1            bytomv1.0                                     ...
# Bytom1           bytomv1.0                                     ...
# Cindicator1      bytomv1.0                                     ...
# ...                                                            ...
# CPChain1         bytomv1.0                                     ...
# Presearch2       bytomv1.0                                     ...
# Electra1         bytomv1.0                                     ...
# Blockmason1      bytomv1.0                                     ...
# Nucleus-Vision1  bytomv1.0                                     ...
#
#                                                        Cindicator1  \
# WeTrust1         hybrid intelligence for\n\neective asset mana...
# Libra4           hybrid intelligence for\n\neective asset mana...
# B2BX1            hybrid intelligence for\n\neective asset mana...
# Bytom1           hybrid intelligence for\n\neective asset mana...
# Cindicator1      hybrid intelligence for\n\neective asset mana...
# ...                                                            ...
# CPChain1         hybrid intelligence for\n\neective asset mana...
# Presearch2       hybrid intelligence for\n\neective asset mana...
# Electra1         hybrid intelligence for\n\neective asset mana...
# Blockmason1      hybrid intelligence for\n\neective asset mana...
# Nucleus-Vision1  hybrid intelligence for\n\neective asset mana...
#
#                                                          iXledger1  \
# WeTrust1          \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# Libra4            \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# B2BX1             \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# Bytom1            \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# Cindicator1       \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# ...                                                            ...
# CPChain1          \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# Presearch2        \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# Electra1          \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# Blockmason1       \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
# Nucleus-Vision1   \n\nan​ ​insurance​ ​marketplace​ ​based​ ​on...
#
#                                                             FARAD1  \
# WeTrust1         farad:\n\ncommoditising forward purchase contr...
# Libra4           farad:\n\ncommoditising forward purchase contr...
# B2BX1            farad:\n\ncommoditising forward purchase contr...
# Bytom1           farad:\n\ncommoditising forward purchase contr...
# Cindicator1      farad:\n\ncommoditising forward purchase contr...
# ...                                                            ...
# CPChain1         farad:\n\ncommoditising forward purchase contr...
# Presearch2       farad:\n\ncommoditising forward purchase contr...
# Electra1         farad:\n\ncommoditising forward purchase contr...
# Blockmason1      farad:\n\ncommoditising forward purchase contr...
# Nucleus-Vision1  farad:\n\ncommoditising forward purchase contr...
#
#                                                         DomRaider1  \
# WeTrust1
# 2\n\nadvance warning\n\nthe initial coin offe...
# Libra4
# 2\n\nadvance warning\n\nthe initial coin offe...
# B2BX1
# 2\n\nadvance warning\n\nthe initial coin offe...
# Bytom1
# 2\n\nadvance warning\n\nthe initial coin offe...
# Cindicator1
# 2\n\nadvance warning\n\nthe initial coin offe...
# ...                                                            ...
# CPChain1
# 2\n\nadvance warning\n\nthe initial coin offe...
# Presearch2
# 2\n\nadvance warning\n\nthe initial coin offe...
# Electra1
# 2\n\nadvance warning\n\nthe initial coin offe...
# Blockmason1
# 2\n\nadvance warning\n\nthe initial coin offe...
# Nucleus-Vision1
# 2\n\nadvance warning\n\nthe initial coin offe...
#
#                                                        Zeusshield1  \
# WeTrust1         zeusshield system\n\nzeusshield smart insuranc...
# Libra4           zeusshield system\n\nzeusshield smart insuranc...
# B2BX1            zeusshield system\n\nzeusshield smart insuranc...
# Bytom1           zeusshield system\n\nzeusshield smart insuranc...
# Cindicator1      zeusshield system\n\nzeusshield smart insuranc...
# ...                                                            ...
# CPChain1         zeusshield system\n\nzeusshield smart insuranc...
# Presearch2       zeusshield system\n\nzeusshield smart insuranc...
# Electra1         zeusshield system\n\nzeusshield smart insuranc...
# Blockmason1      zeusshield system\n\nzeusshield smart insuranc...
# Nucleus-Vision1  zeusshield system\n\nzeusshield smart insuranc...
#
#                                                             Steem1  ...  \
# WeTrust1          \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# Libra4            \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# B2BX1             \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# Bytom1            \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# Cindicator1       \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# ...                                                            ...  ...
# CPChain1          \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# Presearch2        \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# Electra1          \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# Blockmason1       \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
# Nucleus-Vision1   \n \n\n \n\nsteem  \n\nan​ ​incentivized,​ ​b...  ...
#
#                                                               Sky4  \
# WeTrust1         2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# Libra4           2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# B2BX1            2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# Bytom1           2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# Cindicator1      2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# ...                                                            ...
# CPChain1         2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# Presearch2       2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# Electra1         2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# Blockmason1      2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
# Nucleus-Vision1  2016 ieee trustcom/bigdatase/ispa\n2016 ieee t...
#
#                                                            Auctus1  \
# WeTrust1          \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# Libra4            \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# B2BX1             \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# Bytom1            \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# Cindicator1       \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# ...                                                            ...
# CPChain1          \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# Presearch2        \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# Electra1          \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# Blockmason1       \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
# Nucleus-Vision1   \n\n \n \n \n\n \n\n \n\n \n\n \n \n \n  \n \...
#
#                                                           Monetha1  \
# WeTrust1          \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# Libra4            \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# B2BX1             \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# Bytom1            \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# Cindicator1       \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# ...                                                            ...
# CPChain1          \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# Presearch2        \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# Electra1          \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# Blockmason1       \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
# Nucleus-Vision1   \n\n \n\n \n\n \n\n \n\nwhite​ ​paper \n\n \n...
#
#                                                         IoT-Chain1  \
# WeTrust1          \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# Libra4            \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# B2BX1             \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# Bytom1            \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# Cindicator1       \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# ...                                                            ...
# CPChain1          \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# Presearch2        \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# Electra1          \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# Blockmason1       \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
# Nucleus-Vision1   \n \n \n \n\n \n \n \n \n \n \n \n \n \n \n \...
#
#                                                            Status1  \
# WeTrust1         the status network\na strategy towards mass ad...
# Libra4           the status network\na strategy towards mass ad...
# B2BX1            the status network\na strategy towards mass ad...
# Bytom1           the status network\na strategy towards mass ad...
# Cindicator1      the status network\na strategy towards mass ad...
# ...                                                            ...
# CPChain1         the status network\na strategy towards mass ad...
# Presearch2       the status network\na strategy towards mass ad...
# Electra1         the status network\na strategy towards mass ad...
# Blockmason1      the status network\na strategy towards mass ad...
# Nucleus-Vision1  the status network\na strategy towards mass ad...
#
#                                                           CPChain1  \
# WeTrust1         \t\n\ncyber-physical chain (cpchain) whitepape...
# Libra4           \t\n\ncyber-physical chain (cpchain) whitepape...
# B2BX1            \t\n\ncyber-physical chain (cpchain) whitepape...
# Bytom1           \t\n\ncyber-physical chain (cpchain) whitepape...
# Cindicator1      \t\n\ncyber-physical chain (cpchain) whitepape...
# ...                                                            ...
# CPChain1         \t\n\ncyber-physical chain (cpchain) whitepape...
# Presearch2       \t\n\ncyber-physical chain (cpchain) whitepape...
# Electra1         \t\n\ncyber-physical chain (cpchain) whitepape...
# Blockmason1      \t\n\ncyber-physical chain (cpchain) whitepape...
# Nucleus-Vision1  \t\n\ncyber-physical chain (cpchain) whitepape...
#
#                                                         Presearch2  \
# WeTrust1         whitepaper\n\nthe community-powered search eng...
# Libra4           whitepaper\n\nthe community-powered search eng...
# B2BX1            whitepaper\n\nthe community-powered search eng...
# Bytom1           whitepaper\n\nthe community-powered search eng...
# Cindicator1      whitepaper\n\nthe community-powered search eng...
# ...                                                            ...
# CPChain1         whitepaper\n\nthe community-powered search eng...
# Presearch2       whitepaper\n\nthe community-powered search eng...
# Electra1         whitepaper\n\nthe community-powered search eng...
# Blockmason1      whitepaper\n\nthe community-powered search eng...
# Nucleus-Vision1  whitepaper\n\nthe community-powered search eng...
#
#                                                           Electra1  \
# WeTrust1         white paper\n\nrelease 1.0 / january 31, 2018\...
# Libra4           white paper\n\nrelease 1.0 / january 31, 2018\...
# B2BX1            white paper\n\nrelease 1.0 / january 31, 2018\...
# Bytom1           white paper\n\nrelease 1.0 / january 31, 2018\...
# Cindicator1      white paper\n\nrelease 1.0 / january 31, 2018\...
# ...                                                            ...
# CPChain1         white paper\n\nrelease 1.0 / january 31, 2018\...
# Presearch2       white paper\n\nrelease 1.0 / january 31, 2018\...
# Electra1         white paper\n\nrelease 1.0 / january 31, 2018\...
# Blockmason1      white paper\n\nrelease 1.0 / january 31, 2018\...
# Nucleus-Vision1  white paper\n\nrelease 1.0 / january 31, 2018\...
#
#                                                        Blockmason1  \
# WeTrust1         the credit protocol whitepaper v1.0.1\n\nblock...
# Libra4           the credit protocol whitepaper v1.0.1\n\nblock...
# B2BX1            the credit protocol whitepaper v1.0.1\n\nblock...
# Bytom1           the credit protocol whitepaper v1.0.1\n\nblock...
# Cindicator1      the credit protocol whitepaper v1.0.1\n\nblock...
# ...                                                            ...
# CPChain1         the credit protocol whitepaper v1.0.1\n\nblock...
# Presearch2       the credit protocol whitepaper v1.0.1\n\nblock...
# Electra1         the credit protocol whitepaper v1.0.1\n\nblock...
# Blockmason1      the credit protocol whitepaper v1.0.1\n\nblock...
# Nucleus-Vision1  the credit protocol whitepaper v1.0.1\n\nblock...
#
#                                                    Nucleus-Vision1
# WeTrust1         “the full potential of connected devices is on...
# Libra4           “the full potential of connected devices is on...
# B2BX1            “the full potential of connected devices is on...
# Bytom1           “the full potential of connected devices is on...
# Cindicator1      “the full potential of connected devices is on...
# ...                                                            ...
# CPChain1         “the full potential of connected devices is on...
# Presearch2       “the full potential of connected devices is on...
# Electra1         “the full potential of connected devices is on...
# Blockmason1      “the full potential of connected devices is on...
# Nucleus-Vision1  “the full potential of connected devices is on...
#
# [556 rows x 556 columns]

# %%
df1 = pd.DataFrame(df.iloc[0, :])

# %%
df1
# Out:
#                                                           WeTrust1
# WeTrust1         wetrust whitepaper table of contents \n\n \n\n...
# Libra4           state machine replication in the libra\n\nbloc...
# B2BX1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bytom1           bytomv1.0                                     ...
# Cindicator1      hybrid intelligence for\n\neective asset mana...
# ...                                                            ...
# CPChain1         \t\n\ncyber-physical chain (cpchain) whitepape...
# Presearch2       whitepaper\n\nthe community-powered search eng...
# Electra1         white paper\n\nrelease 1.0 / january 31, 2018\...
# Blockmason1      the credit protocol whitepaper v1.0.1\n\nblock...
# Nucleus-Vision1  “the full potential of connected devices is on...
#
# [556 rows x 1 columns]

# %%
df1.rename(columns= {'WeTrust1' : 'Text Corpus'})
# Out:
#                                                        Text Corpus
# WeTrust1         wetrust whitepaper table of contents \n\n \n\n...
# Libra4           state machine replication in the libra\n\nbloc...
# B2BX1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 23\n\n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bytom1           bytomv1.0                                     ...
# Cindicator1      hybrid intelligence for\n\neective asset mana...
# ...                                                            ...
# CPChain1         \t\n\ncyber-physical chain (cpchain) whitepape...
# Presearch2       whitepaper\n\nthe community-powered search eng...
# Electra1         white paper\n\nrelease 1.0 / january 31, 2018\...
# Blockmason1      the credit protocol whitepaper v1.0.1\n\nblock...
# Nucleus-Vision1  “the full potential of connected devices is on...
#
# [556 rows x 1 columns]

# %%
os.chdir('/Users/alisdghnia/Desktop/')

# %%
df1.to_csv('Files Texts Dataframe.csv')
