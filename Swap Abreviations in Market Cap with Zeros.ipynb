# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/Users/alisdghnia/Desktop/')

# %%
df = pd.read_excel('Full Dataset with Independent and dependent variables.xlsx')

# %%
df.dtypes
# Out:
# Unnamed: 0                               int64
# Name                                    object
# File Size (MB)                         float64
# Number of Pages                          int64
# Word Count                               int64
# Flesch Reading Ease                    float64
# New Dale-Chall                         float64
# Abstract Section                          bool
# Summary Section                           bool
# Reference Section                         bool
# Crypto Name                             object
# Price (Intraday)                       float64
# % Change                               float64
# Market Cap                              object
# Volume in Currency (Since 0:00 UTC)     object
# Volume in Currency (24Hr)               object
# Total Volume All Currencies (24Hr)      object
# Circulating Supply                      object
# dtype: object

# %%
df['Market Cap'] = df['Market Cap'].apply(lambda x: x.replace('M', str(000000)).replace('B', str(000000000))
                                if isinstance(x, str) else x).astype(float)

# %%
df.dtypes
# Out:
# Unnamed: 0                               int64
# Name                                    object
# File Size (MB)                         float64
# Number of Pages                          int64
# Word Count                               int64
# Flesch Reading Ease                    float64
# New Dale-Chall                         float64
# Abstract Section                          bool
# Summary Section                           bool
# Reference Section                         bool
# Crypto Name                             object
# Price (Intraday)                       float64
# % Change                               float64
# Market Cap                             float64
# Volume in Currency (Since 0:00 UTC)     object
# Volume in Currency (24Hr)               object
# Total Volume All Currencies (24Hr)      object
# Circulating Supply                      object
# dtype: object

# %%
df
# Out:
#      Unnamed: 0                 Name  File Size (MB)  Number of Pages  \
# 0             0         WeTrust1.pdf        1.342260               40
# 1             1           Libra4.pdf        0.293671               41
# 2             2            B2BX1.pdf       15.404950               42
# 3             3           Bytom1.pdf        0.374002               17
# 4             4      Cindicator1.pdf        1.123809               37
# ..          ...                  ...             ...              ...
# 551         551         CPChain1.pdf        1.195266               34
# 552         552       Presearch2.pdf        5.291211               39
# 553         553         Electra1.pdf        0.624846               34
# 554         554      Blockmason1.pdf        3.355893               31
# 555         555  Nucleus-Vision1.pdf        0.900639                1
#
#      Word Count  Flesch Reading Ease  New Dale-Chall  Abstract Section  \
# ...

# %%
value_list = df['Market Cap'].tolist()

# %%
for value in value_list:
    map = {'M': 1000000, 'B': 1000000000}
    print(value * map[value[-1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 9 in <cell line: 1>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=0'>1</a> for value in value_list:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=1'>2</a>     map = {'M': 1000000, 'B': 1000000000}
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=2'>3</a>     print(value * map[value[-1]])
#
# TypeError: 'int' object is not subscriptable
